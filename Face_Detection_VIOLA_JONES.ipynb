# %%
# !pip uninstall -y opencv-python

# %%
# !pip install opencv-python==3.4.3.18

# %%
import os
import cv2
from imutils import paths
from google.colab.patches import cv2_imshow

# %% [markdown]
# ### Downloading Haarcascade XML Files From -
# https://github.com/opencv/opencv/tree/master/data/haarcascades

# %%
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
image_paths="/content/Faces_Dataset"

# %% [markdown]
# ## For Each Image -
#
#     1. Reading the image frame by frame
#     2. Converting each image frame to GRAY scale
#     3. Using Cascade converting each face into rectangles
#     4. Plotting the recatangles

# %%
for path in sorted(list(paths.list_images(image_paths))):
  frame = cv2.imread(path) #Capturing frame by frame
  gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY) #Cpnverting each image frame to gray scale
  faces = faceCascade.detectMultiScale(gray,scaleFactor=1.05, minNeighbors=5, minSize=(30, 30), flags=cv2.CASCADE_SCALE_IMAGE)
  for (x,y,w,h) in faces: 
    cv2.rectangle(frame, (x, y), (x + w, y + h),(0,255,0), 2)

# %% [markdown]
# ### Displaying the Frame

# %%
cv2_imshow(frame)
# Out:
# <PIL.Image.Image image mode=RGB size=535x314 at 0x7FDBEDA9FA50>
